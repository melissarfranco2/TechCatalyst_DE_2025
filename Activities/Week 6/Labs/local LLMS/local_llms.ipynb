# %%
from ollama import chat

model = 'smollm2:135m'

# %%
# Function to generate an email
def generate_email(subject, recipient_name, additional_info):
    # Step 1: Create the prompt to guide the AI in generating the email
    prompt = f"Write a professional email to {recipient_name} with the subject '{subject}'. Include the following information: {additional_info}"
    
    # Step 2: Call the OpenAI API to generate the email
    # Hint: Use the 'chat' endpoint to create a completion based on the prompt
    response = chat(
        model= model, 
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": prompt},
        ],
    )
    
    # Step 3: Extract and return the generated email content from the API response
    return response['message']['content']

# Function to start the email writing assistant
def email_writing_assistant():
    print("Welcome to the Email Writing Assistant!\n")
    
    # Step 4: Gather user input for the email subject, recipient name, and additional information
    subject = input('Enter the subject of the email: ')
    recipient_name = input('Enter the recipient name: ')
    additional_info = input('Enter any additional info: ')
    
    # Step 5: Call the 'generate_email' function and display the generated email
    email = generate_email(subject, recipient_name, additional_info)
    print(f"Email:\n{email}")

# Start the email writing assistant
email_writing_assistant()
# Out:
# Welcome to the Email Writing Assistant!
#
# Email:
# Subject: "Wishing her a great day ahead"
#
# Dear Jessica,
#
# I hope this message finds you well. I am writing to wish you a good day filled with opportunities and smiles in your life.
#
# Since returning from our research expedition aboard the research vessel, I had the pleasure of observing some remarkable developments during our stay onboard. You have been working diligently on your research, contributing significantly to the field, and I believe that you are an exceptional individual who will continue to make valuable contributions to the field once you complete your studies.
#
# Your work in this area has inspired me greatly. I hope that your findings align with our project goals and provide insights into potential areas of future research.
#
# I am writing to wish you success, as well as a great day ahead for your continued success in your chosen profession. As we have learned so much since leaving the field, I strongly believe that it is crucial for all professionals like yourself to continue advancing their careers through dedicated and consistent work over time.
#
# Thank you for your attention to this opportunity, and may God bless you always!
#
# Sincerely,
# [Your Name]

# %%
# Function to generate an email
def generate_email(subject, recipient_name, additional_info, input_tone):
    # Step 1: Create the prompt to guide the AI in generating the email
    prompt = f"Write a professional email to {recipient_name} with the subject '{subject}'. Include the following information: {additional_info}"
    
    # Step 2: Call the OpenAI API to generate the email
    # Hint: Use the 'chat' endpoint to create a completion based on the prompt
    response = chat(
        model= model, 
        messages=[
            {"role": "system", "content": f"You are a helpful assistant. Always reply in a {input_tone} tone "},
            {"role": "user", "content": prompt},
        ],
    )
    
    # Step 3: Extract and return the generated email content from the API response
    return response['message']['content']

# Function to start the email writing assistant
def email_writing_assistant():
    print("Welcome to the Email Writing Assistant!\n")
    
    # Step 4: Gather user input for the email subject, recipient name, and additional information
    subject = input('Enter the subject of the email: ')
    recipient_name = input('Enter the recipient name: ')
    additional_info = input('Enter any additional info: ')
    input_tone = input("What tone would you like for this email?")
    
    # Step 5: Call the 'generate_email' function and display the generated email
    email = generate_email(subject, recipient_name, additional_info, input_tone)
    print(f"Email:\n{email}")

# Start the email writing assistant
email_writing_assistant()
# Out:
# Welcome to the Email Writing Assistant!
#
# Email:
# Dear Jessica,
#
# I hope this email finds you well. I recently attended the "How To Master the Art of Spanish Cooking" workshop hosted by the culinary school and had an incredible time. I’ve been studying Spanish for several years now and have found it incredibly rewarding to combine my passion for food with language learning.
#
# As we discussed, I believe there is a significant gap in our respective skill levels between the two areas – English-speaking individuals are often missing out on valuable knowledge of Spanish grammar and vocabulary while non-English speakers may struggle more significantly due to limited exposure to the language itself.
#
# I’d love to hear your thoughts on how we can better support this specific challenge for both of us. If you have any suggestions or resources that might help, I would greatly appreciate it!
#
# Best regards,
# [Your Name]

# %%
# Function to generate an email
def generate_email(subject, recipient_name, additional_info, input_tone, critical_date):
    # Step 1: Create the prompt to guide the AI in generating the email
    prompt = f"Write a professional email to {recipient_name} with the subject '{subject}' and '{critical_date}'. Include the following information: {additional_info}"
    
    # Step 2: Call the OpenAI API to generate the email
    # Hint: Use the 'chat' endpoint to create a completion based on the prompt
    response = chat(
        model= model, 
        messages=[
            {"role": "system", "content": f"You are a helpful assistant. Always reply in a {input_tone} tone "},
            {"role": "user", "content": prompt},
        ],
    )
    
    # Step 3: Extract and return the generated email content from the API response
    return response['message']['content']

# Function to start the email writing assistant
def email_writing_assistant():
    print("Welcome to the Email Writing Assistant!\n")
    
    # Step 4: Gather user input for the email subject, recipient name, and additional information
    subject = input('Enter the subject of the email: ')
    recipient_name = input('Enter the recipient name: ')
    additional_info = input('Enter any additional info: ')
    input_tone = input("What tone would you like for this email?")
    critical_date = input('Enter the critical date: ')
    
    # Step 5: Call the 'generate_email' function and display the generated email
    email = generate_email(subject, recipient_name, additional_info, input_tone, critical_date)
    print(f"Email:\n{email}")

# Start the email writing assistant
email_writing_assistant()
# Out:
# Welcome to the Email Writing Assistant!
#
# Email:
# Dear Jessica,
#
# I hope this message finds you well. I’m writing to let you know that I noticed some interesting developments in our friendship after meeting at the same coffee shop a few weeks back. As you know, we have quite different personalities, but I do think we share a mutual interest in history and literature.
#
# Since then, I’ve been giving you a lot of thought about your work on the local museum exhibit. I understand that you must be busy with your studies, so could you help me out? If there are any resources or materials available that might be useful to you, I would greatly appreciate them.
#
# I value our friendship and hope we can continue to collaborate on these matters in the future. I’m sure you’ll enjoy the process of working together with me.
#
# Best regards,
# Emily
